# %% [markdown]
# # Endpoint Workflow
#
# This notebook demonstrates the contributor workflow for adding endpoints.
# Based on `docs/10-tutorials/tutorial-8-endpoint-workflow.md`.
#
# **Learning Objectives:**
# - Choose the correct surface (XRPC vs `/api/pds/*` vs `/ui`)
# - Find registration points in code
# - Use deciduous to track endpoint work
#
# **Estimated Time:** 45-60 minutes

# %% [markdown]
# ## Step 1: Choose the Surface
#
# $$
# \text{Feature} \xrightarrow{\text{decide}} \begin{cases} \text{XRPC} & \text{protocol method} \\ \text{/api/pds/*} & \text{debug/inspect} \\ \text{/ui} & \text{contributor tooling} \end{cases}
# $$

# %%
// deciduous: Track your endpoint work
// Equivalent to: deciduous add goal "Implement endpoint" -c 95
NSLog(@"Goal tracked in deciduous graph");

// Find registration point
// XRPC: XrpcMethodRegistry
// UI: PDSHttpServerBuilder
NSLog(@"Registration point identified");

# %%
// Validation and rate limiting
// PDSInputValidator provides guard rails
BOOL valid = YES;
if (valid) {
    NSLog(@"Input validated");
} else {
    NSLog(@"Validation failed");
}

# %% [markdown]
# ## Contributor Checklist
#
# | Step | Action | Tool |
# |------|--------|------|
# | 1 | Decide surface | deciduous |
# | 2 | Change runtime | Xcode/editor |
# | 3 | Add tests | Xcode/test |
# | 4 | Expose via tooling | scripts/ |
# | 5 | Update docs | docs/ |
