# %% [markdown]
# # Account Management
#
# This notebook demonstrates account lifecycle concepts from Garazyk.
# Based on `docs/10-tutorials/tutorial-2-accounts.md`.
#
# **Learning Objectives:**
# - Understand account creation and session management
# - Trace `createAccount` and `createSession` flows
# - Verify account behavior with checks
#
# **Estimated Time:** 35-45 minutes

# %% [markdown]
# ## Architecture
#
# $$
#  \text{Client} \xrightarrow{\text{XRPC}} \text{PDSAccountService} \xrightarrow{\text{DB}} \text{Service database}
# $$
#
# | Step | Component | Responsibility |
# |------|------------|------------------|
# | 1 | XRPC server | Route `com.atproto.identity.createAccount` |
# | 2 | PDSAccountService | Validate input, create account |
# | 3 | Service DB | Persist account record |
# | 4 | JWT helpers | Issue session token |

# %%
// Simulate account service call patterns
// (In real Garazyk, this is handled by PDSAccountService)
NSString *handle = @"user.example.com";
NSLog(@"Handle: %@", handle);

// Session creation simulation
BOOL sessionValid = YES;
NSLog(@"Session valid: %d", sessionValid);

// Invite policy check
BOOL inviteRequired = NO;
if (inviteRequired) {
    NSLog(@"Invite required");
} else {
    NSLog(@"Open registration");
}
